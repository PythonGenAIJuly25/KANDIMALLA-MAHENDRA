# %% [markdown]
# # Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!.")
# Out:
# Hello, World!.

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name=input("Enter name : ")
print(name)
# Out:
# Enter name : Mahendra
# Mahendra

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
n=int(input("enter number :"))
if n>0 :
  print(n,"is positive number")
elif n<0:
  print(n,"is negative number")
else:
  print(n,"is zero")
# Out:
# enter number :34
# 34 is positive number

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a=20
b=45
c=5
if a>b and a>c:
  print("Big number is",a)
elif b>c:
  print("Big number is",b)
else:
  print("Big number is",c)
# Out:
# Big number is 45

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
n=int(input("enter number"))
print("The factorials are : ",end=" ")
for i in range(1,n+1):
  if n%i==0:
    print(i,end=",")
# Out:
# enter number56
# The factorials are :  1,2,4,7,8,14,28,56,

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a=10
b=23.67
c="mahi"
d=True
print("Type is ",type(a),"value is",a)
print("Type is ",type(b),"value is",b)
print("Type is ",type(c),"value is",c)
print("Type is ",type(d),"value is",d)
# Out:
# Type is  <class 'int'> value is 10
# Type is  <class 'float'> value is 23.67
# Type is  <class 'str'> value is mahi
# Type is  <class 'bool'> value is True

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=10
b=20
print(f"Before Swapping a = {a} and b={b}")

t=a
a=b
b=t

print(f"After Swapping a = {a} and b={b}")
# Out:
# Before Swapping a = 10 and b=20
# After Swapping a = 20 and b=10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cel=float(input("Engter Celsius"))

f=cel * 1.8 +32

print("Fahrenheit is ",f)
# Out:
# Engter Celsius24
# Fahrenheit is  75.2

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1="mahendra"
str2="kandimalla"
str3=str1+" "+str2
print("concatenate string is ",str3)
# Out:
# concatenate string is  mahendra kandimalla

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
n=10
print(type(n)==int)
# Out:
# True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
n1=int(input("enter num1 : "))
n2=int(input("enter num2 : "))
print("Addition is ",n1+n2)
print("Subtraction is ",n1-n2)
print("Multiplication is ",n1*n2)
print("Division is ",n1/n2)
# Out:
# enter num1 : 12
# enter num2 : 12
# Addition is  24
# Subtraction is  0
# Multiplication is  144
# Division is  1.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
n1=int(input("enter number 1 : "))
n2=int(input("enter number 2 : "))
if n1==n2:
  print("Two numbers are equal")
elif n1!=n2:
  print("Two numbers are not equal")
  if n1 > n2:
    print(n1,"is greater than",n2)
  else:
    print(n2,"is greater than",n1)
# Out:
# enter number 1 : 24
# enter number 2 : 52
# Two numbers are not equal
# 52 is greater than 24

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a=10
b=-6
if (a>0 and b<=10):
  print(a," is between in 1 and 10")
if b<0 or b>10:
  print(b," is not between in 1 and 10")

if not b:
  print("False")
else:
  print("True")
# Out:
# 10  is between in 1 and 10
# -6  is not between in 1 and 10
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
n=10
print("square number is ",n**2)
# Out:
# square number is  100

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
n=int(input())
if n%2==0:
  print(n,"is Even number")
else:
  print(n,"is odd number")
# Out:
# 35
# 35 is odd number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n=int(input())
s=0
for i in range(n):
  s=s+i
print("sum of the first",n,"natural numbers",s)
# Out:
# 34
# sum of the first 34 natural numbers 561

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
n=int(input("enter year : "))
if (n%4==0 and n%100!=0) or n%400==0:
  print(n,"is Leap year")
else:
  print(n,"is not  Leap year")
# Out:
# enter year : 1900
# 1900 is not  Leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
s=input("Enter String : ")
print("Reversed String is ",s[::-1])
# Out:
# Enter String : mahendra
# Reversed String is  ardneham

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
s=input("Enter String : ")
if s==s[::-1]:
  print(s,"is a palindrome")
else:
  print(s,"is not a palindrome")
# Out:
# Enter String : mahendra
# mahendra is not a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code herel
list_ele=list(map(int,input("Enter list elements separated by space").split(' ')))
list_ele.sort()
print("sorting list in asc order is ",list_ele)
# Out:
# Enter list elements separated by space1 3 2
# sorting list in asc order is  [1, 2, 3]
